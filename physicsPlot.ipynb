# %%
import physics
import numpy as np

# %%
print(
            physics.calculate_auv2_acceleration(
                [0, 50, 50, 0], np.pi / 4, 0, 100
            )
        )
# Out:
# [ 0.         -0.70710678]

# %%
t, x, y, theta, v, omega, a = physics.simulate_auv2_motion([50,30,40,25], 0.2, 1, 0.5)
print(f"x: {x}")
print(f"y: {y}")
physics.plot_auv2_motion(t, x, y, theta, v, omega, a)
# Out:
# x: [0.00000000e+00 0.00000000e+00 1.47009987e-03 4.41029960e-03
#  8.82059920e-03 1.47007550e-02 2.20502538e-02 3.08682622e-02
#  4.11535492e-02 5.29043844e-02 6.61184102e-02 8.07924895e-02
#  9.69225280e-02 1.14503273e-01 1.33528086e-01 1.53988698e-01
#  1.75874935e-01 1.99174432e-01 2.23872319e-01 2.49950899e-01
#  2.77389306e-01 3.06163155e-01 3.36244182e-01 3.67599886e-01
#  4.00193169e-01 4.33981985e-01 4.68919002e-01 5.04951288e-01
#  5.42020022e-01 5.80060249e-01 6.19000680e-01 6.58763543e-01
#  6.99264515e-01 7.40412721e-01 7.82110832e-01 8.24255262e-01
#  8.66736476e-01 9.09439425e-01 9.52244118e-01 9.95026326e-01
#  1.03765845e+00 1.08001052e+00 1.12195141e+00 1.16335011e+00
#  1.20407723e+00 1.24400666e+00 1.28301727e+00 1.32099482e+00
#  1.35783388e+00 1.39343989e+00 1.42773117e+00 1.46064093e+00
#  1.49211927e+00 1.52213499e+00 1.55067726e+00 1.57775705e+00
#  1.60340829e+00 1.62768860e+00 1.65067967e+00 1.67248711e+00
# ...
